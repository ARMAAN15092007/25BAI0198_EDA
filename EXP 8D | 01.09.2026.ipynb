# %% [markdown]
# <a href="https://colab.research.google.com/github/ARMAAN15092007/25BAI0198_EDA/blob/main/EXP%208D%20%7C%2001.09.2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

df = pd.read_csv("/content/mnist-dataset.ipynb")
display(df.head())
# Out:
# Empty DataFrame
# ...

# %%
import time
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.decomposition import PCA

# %%
pca_95 = PCA(n_components=0.95)
x_train_pca = pca_95.fit_transform(x_train_flat)
x_test_pca = pca_95.transform(x_test_flat)

# %%
clf_orig = SVC(kernel='rbf')
start = time.time()
clf_orig.fit(x_train_flat[:10000], y_train[:10000])
train_time_orig = time.time() - start

# %%
start = time.time()
preds_orig = clf_orig.predict(x_test_flat[:2000])
pred_time_orig = time.time() - start
acc_orig = accuracy_score(y_test[:2000], preds_orig)

# %%
clf_pca = SVC(kernel='rbf')
start = time.time()
clf_pca.fit(x_train_pca[:10000], y_train[:10000])
train_time_pca = time.time() - start

# %%
start = time.time()
preds_pca = clf_pca.predict(x_test_pca[:2000])
pred_time_pca = time.time() - start
acc_pca = accuracy_score(y_test[:2000], preds_pca)

# %%
print(f"Original Data -> Acc: {acc_orig:.4f}, Train Time: {train_time_orig:.2f}s, Pred Time: {pred_time_orig:.2f}s")
print(f"PCA Data -> Acc: {acc_pca:.4f}, Train Time: {train_time_pca:.2f}s, Pred Time: {pred_time_pca:.2f}s")
# Out:
# Original Data -> Acc: 0.9445, Train Time: 20.63s, Pred Time: 15.10s
# PCA Data -> Acc: 0.9540, Train Time: 10.26s, Pred Time: 3.01s
