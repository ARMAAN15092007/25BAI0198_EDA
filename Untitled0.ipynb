# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

employee_data = {
    "EmployeeID": [101, 102, 103, 104, 105],
    "Name": ["John", "Alice", "David", "Emma", "Michael"],
    "Department": ["HR", "IT", "Finance", "Marketing", "Sales"],
    "Age": [25, 30, 28, 35, 27],
    "Experience": [2, 5, 4, 10, 3],
    "Salary": [35000, 60000, 55000, 75000, 42000],
    "Gender": ["Male", "Female", "Male", "Female", "Male"],
    "City": ["Chennai", "Bangalore", "Hyderabad", "Mumbai", "Delhi"]
}
df = pd.DataFrame(employee_data)

# %%
df.head()
# Out:
#    EmployeeID     Name Department  Age  Experience  Salary  Gender       City
# 0         101     John         HR   25           2   35000    Male    Chennai
# 1         102    Alice         IT   30           5   60000  Female  Bangalore
# 2         103    David    Finance   28           4   55000    Male  Hyderabad
# 3         104     Emma  Marketing   35          10   75000  Female     Mumbai
# 4         105  Michael      Sales   27           3   42000    Male      Delhi

# %%
df.tail()
# Out:
#    EmployeeID     Name Department  Age  Experience  Salary  Gender       City
# 0         101     John         HR   25           2   35000    Male    Chennai
# 1         102    Alice         IT   30           5   60000  Female  Bangalore
# 2         103    David    Finance   28           4   55000    Male  Hyderabad
# 3         104     Emma  Marketing   35          10   75000  Female     Mumbai
# 4         105  Michael      Sales   27           3   42000    Male      Delhi

# %%
df.dtypes
# Out:
# EmployeeID     int64
# Name          object
# Department    object
# Age            int64
# Experience     int64
# Salary         int64
# Gender        object
# City          object
# dtype: object

# %%
df.describe()
# Out:
#        EmployeeID        Age  Experience        Salary
# count    5.000000   5.000000    5.000000      5.000000
# mean   103.000000  29.000000    4.800000  53400.000000
# std      1.581139   3.807887    3.114482  15662.056059
# min    101.000000  25.000000    2.000000  35000.000000
# 25%    102.000000  27.000000    3.000000  42000.000000
# 50%    103.000000  28.000000    4.000000  55000.000000
# 75%    104.000000  30.000000    5.000000  60000.000000
# max    105.000000  35.000000   10.000000  75000.000000

# %%
df.max()
# Out:
# EmployeeID        105
# Name          Michael
# Department      Sales
# Age                35
# Experience         10
# Salary          75000
# Gender           Male
# City           Mumbai
# dtype: object

# %%
df.min()
# Out:
# EmployeeID          101
# Name              Alice
# Department      Finance
# Age                  25
# Experience            2
# Salary            35000
# Gender           Female
# City          Bangalore
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  5 non-null      int64
#  1   Name        5 non-null      object
#  2   Department  5 non-null      object
#  3   Age         5 non-null      int64
#  4   Experience  5 non-null      int64
#  5   Salary      5 non-null      int64
#  6   Gender      5 non-null      object
#  7   City        5 non-null      object
# dtypes: int64(4), object(4)
# memory usage: 452.0+ bytes
