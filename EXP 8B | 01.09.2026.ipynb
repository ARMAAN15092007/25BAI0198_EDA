# %% [markdown]
# <a href="https://colab.research.google.com/github/ARMAAN15092007/25BAI0198_EDA/blob/main/EXP%208B%20%7C%2001.09.2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

df = pd.read_csv("/content/mnist-dataset.ipynb")
display(df.head())
# Out:
# Empty DataFrame
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(x_train_flat)
# Out:
# PCA()

# %%
individual_variance = pca.explained_variance_ratio_
cumulative_variance = np.cumsum(individual_variance)

# %%
print("Variance explained by first 10 components:")
print(individual_variance[:10])
# Out:
# Variance explained by first 10 components:
# [0.09704664 0.07095924 0.06169089 0.05389419 0.04868797 0.04312231
#  0.0327193  0.02883895 0.02762029 0.02357001]

# %%
for target in [0.90, 0.95, 0.99]:
    components = np.argmax(cumulative_variance >= target) + 1
    print(f"Components required for {int(target*100)}% variance: {components}")
# Out:
# Components required for 90% variance: 87
# Components required for 95% variance: 154
# Components required for 99% variance: 331

# %%
pca_2d = PCA(n_components=2)
x_train_pca_2d = pca_2d.fit_transform(x_train_flat)

# %%
pca_50d = PCA(n_components=50)
x_train_pca_50d = pca_50d.fit_transform(x_train_flat)

# %%
plt.figure(figsize=(6, 4))
plt.plot(individual_variance[:100], marker='o', linestyle='-')
plt.title('Scree Plot')
plt.xlabel('Principal Component')
plt.ylabel('Explained Variance Ratio')
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(cumulative_variance, marker='', linestyle='-')
plt.axhline(y=0.95, color='r', linestyle='--')
plt.title('Cumulative Explained Variance')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Variance')
plt.show()

# %%
plt.figure(figsize=(8, 6))
scatter = plt.scatter(x_train_pca_2d[:, 0], x_train_pca_2d[:, 1], c=y_train, cmap='tab10', alpha=0.5, s=1)
plt.colorbar(scatter)
plt.title('2D PCA Projection')
plt.xlabel('PC 1')
plt.ylabel('PC 2')
plt.show()
