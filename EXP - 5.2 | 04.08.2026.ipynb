# %% [markdown]
# <a href="https://colab.research.google.com/github/ARMAAN15092007/25BAI0198_EDA/blob/main/EXP_5_2_%7C_04_08_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
from collections import Counter
# %matplotlib inline
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

data = {
'Age': [25, 30, 45, 35, 22],
'Salary': [50000, 64000, 120000, 85000, 1200000] # 1,200,000 is an outlier
}
df = pd.DataFrame(data)
print("Original Data:\n", df, "\n")
# Out:
# Original Data:
#     Age   Salary
# 0   25    50000
# 1   30    64000
# 2   45   120000
# 3   35    85000
# 4   22  1200000

# %%
min_max_scaler = MinMaxScaler()
df_min_max = pd.DataFrame(
min_max_scaler.fit_transform(df),
columns=df.columns
)
print("Min-Max Scaled Data:\n", df_min_max, "\n")
# Out:
# Min-Max Scaled Data:
#          Age    Salary
# 0  0.130435  0.000000
# 1  0.347826  0.012174
# 2  1.000000  0.060870
# 3  0.565217  0.030435
# 4  0.000000  1.000000

# %%
standard_scaler = StandardScaler()
df_standard = pd.DataFrame(
standard_scaler.fit_transform(df),
columns=df.columns
)
print("Standardized Data:\n", df_standard, "\n")
# Out:
# Standardized Data:
#          Age    Salary
# 0 -0.788742 -0.565609
# 1 -0.172537 -0.534409
# 2  1.676077 -0.409609
# 3  0.443667 -0.487609
# 4 -1.158465  1.997236

# %%
data = {
    'StoreSales': [1200, 1500, 1100, 1350, 95000, 1400, 1250, 1600, 1300, 45000]
}
df = pd.DataFrame(data)

Q1 = df['StoreSales'].quantile(0.25)
Q3 = df['StoreSales'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

outliers_iqr = df[(df['StoreSales'] < lower_bound) | (df['StoreSales'] > upper_bound)]
print(outliers_iqr)
# Out:
#    StoreSales
# 4       95000
# 9       45000

# %%
import pandas as pd
from scipy.stats import median_abs_deviation

data = {
    'HousePrices': [250000, 270000, 310000, 290000, 260000, 8500000, 280000]
}
df = pd.DataFrame(data)

median = df['HousePrices'].median()
mad = median_abs_deviation(df['HousePrices'])

mod_z_scores = 0.6745 * (df['HousePrices'] - median) / mad
outliers_mod_z = df[abs(mod_z_scores) > 3.5]
print(outliers_mod_z)
# Out:
#    HousePrices
# 5      8500000
