# %% [markdown]
# <a href="https://colab.research.google.com/github/ARMAAN15092007/25BAI0198_EDA/blob/main/EXP%208C%20%7C%2001.09.2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

df = pd.read_csv("/content/mnist-dataset.ipynb")
display(df.head())
# Out:
# Empty DataFrame
# ...

# %%
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
x_subset = x_train_flat[:3000]
y_subset = y_train[:3000]

# %%
x_pca_subset = x_train_pca_50d[:3000]

# %%
for p in [5, 30, 50]:
    tsne_orig = TSNE(n_components=2, perplexity=p, random_state=42)
    x_tsne_orig = tsne_orig.fit_transform(x_subset)
    plt.figure(figsize=(6, 5))
    plt.scatter(x_tsne_orig[:, 0], x_tsne_orig[:, 1], c=y_subset, cmap='tab10', alpha=0.6, s=2)
    plt.title(f"t-SNE (Original Data) - Perplexity: {p}")
    plt.colorbar()
    plt.show()

# %%
for p in [5, 30, 50]:
    tsne_pca = TSNE(n_components=2, perplexity=p, random_state=42)
    x_tsne_pca = tsne_pca.fit_transform(x_pca_subset)

    plt.figure(figsize=(6, 5))
    plt.scatter(x_tsne_pca[:, 0], x_tsne_pca[:, 1], c=y_subset, cmap='tab10', alpha=0.6, s=2)
    plt.title(f"t-SNE (PCA-Reduced Data) - Perplexity: {p}")
    plt.colorbar()
    plt.show()
