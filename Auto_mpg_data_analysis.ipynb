# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv('/content/auto-mpg.csv')

# %%
df.shape
# Out:
# (398, 9)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
df.value_counts()
# Out:
# mpg   cylinders  displacement  horsepower  weight  acceleration  model year  origin  car name
# 46.6  4          86.0          65          2110    17.9          80          3       mazda glc                           1
# 9.0   8          304.0         193         4732    18.5          70          1       hi 1200d                            1
# 10.0  8          307.0         200         4376    15.0          70          1       chevy c20                           1
#                  360.0         215         4615    14.0          70          1       ford f250                           1
# 11.0  8          318.0         210         4382    13.5          70          1       dodge d200                          1
#                                                                                                                         ..
# 13.0  8          318.0         150         3940    13.2          76          1       plymouth volare premier v8          1
# ...

# %%
df.tail(5)
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin         car name
# 393          82       1  ford mustang gl
# 394          82       2        vw pickup
# 395          82       1    dodge rampage
# 396          82       1      ford ranger
# 397          82       1       chevy s-10

# %%
df.value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='mpg,cylinders,displacement,horsepower,weight,acceleration,model year,origin,car name'>
